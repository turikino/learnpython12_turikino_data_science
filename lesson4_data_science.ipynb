# %%
import json
import pandas as pd

# %%
with open('data_397_2019_02_01.json', 'r', encoding='cp1251') as f:
    data = json.load(f)

# %%
data
# Out:
# [{'global_id': 1773538,
#   'NameOfStation': 'Китай-город',
#   'ModeOnEvenDays': 'открытие в 05:30:00; закрытие в 01:00:00; первый поезд по 1 пути в 05:44:00, по 2 пути в 05:49:05; последний поезд по 1 пути в 01:35:10, по 2 пути в 01:26:20',
#   'Name': 'Китай-город, вход-выход 3 в северный вестибюль',
#   'Longitude_WGS84': '37.6309849',
#   'Latitude_WGS84': '55.7567672',
#   'ModeOnOddDays': 'открытие в 05:30:00; закрытие в 01:00:00; первый поезд по 1 пути в 05:43:10, по 2 пути в 05:49:50; последний поезд по 1 пути в 01:35:10, по 2 пути в 01:26:20',
#   'ID': 326,
#   'Line': 'Калужско-Рижская линия',
#   'LittleFunctionalBPAAmount': 4,
#   'BPAAmount': 4,
#   'RepairOfEscalators': [],
#   'geoData': {'type': 'Point', 'coordinates': [37.6309849, 55.7567672]}},
#  {'global_id': 1773539,
#   'NameOfStation': 'Китай-город',
# ...

# %%
repairing_escalators = []

# %%
for station in data:
    if station['RepairOfEscalators']:
        repairing_escalators.append(station)

# %%
repairing_escalators
# Out:
# [{'global_id': 1773613,
#   'NameOfStation': 'Динамо',
#   'ModeOnEvenDays': 'открытие в 05:25:00; закрытие в 01:00:00; первый поезд по 1 пути в 05:58:35, по 2 пути в 05:33:20; последний поезд по 1 пути в 01:49:15, по 2 пути в 01:47:25',
#   'Name': 'Динамо, вход в северный вестибюль',
#   'Longitude_WGS84': '37.556447',
#   'Latitude_WGS84': '55.790523',
#   'ModeOnOddDays': 'открытие в 05:25:00; закрытие в 01:00:00; первый поезд по 1 пути в 05:58:35, по 2 пути в 05:33:20; последний поезд по 1 пути в 01:49:15, по 2 пути в 01:16:10',
#   'ID': 125,
#   'Line': 'Замоскворецкая линия',
#   'LittleFunctionalBPAAmount': 5,
#   'BPAAmount': 5,
#   'RepairOfEscalators': [{'RepairOfEscalators': '20.12.2018-21.02.2019'}],
#   'geoData': {'type': 'Point', 'coordinates': [37.556447, 55.790523]}},
#  {'global_id': 1773658,
#   'NameOfStation': 'Красногвардейская',
# ...
